# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaOlarte/Ciencia_de_datos/blob/main/taller_2_introducci_n_a_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ANÁLISIS EXPLORATORIO DE DATOS - EDA
# "Conjunto de técnicas estadísticas cuyo objetivo es explorar, describir y resumir la naturaleza de los datos y comprender las relaciones existentes entre las variables de interés, maximizando la comprensión del conjunto de datos".
#
# El EDA, de acuoerdo a Wickman y Çetinkaya-Rundel y Grolemund (2023) propone seguir los siguientes pasos:
# 1. **Realizar un análisis descriptivo de las variables**, con el fin de obtener una idea representativa de los datos.
# 2. **Re-ajustar tipos de variables** para que sean consistentes en el momento de realizar posteriores operaciones.
# 3. **Detectar y tratar datos ausentes**, que nos permitirá procesar adecuadamente las variables numéricas.
# 4. **Identificar datos atípicos y tratarlos de forma adecuada**. Esto mitigará la distorsión de futuros análisis estadísticos.
# 5. **Realizar un examen numérico y gráfico de las relaciones entre variables analizadas para determinar el grado de correlación entre ellas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##TALLER
# Para ello, realizaremos un ejercicio en el cuál se analizará estudiaremos el dataset de titanic con el fin de poder responder a la siguiente pregunta: Podría Jack sobrevivir al hundimiento del TITANIC (de acuerdo a lo arrojado por los datos).
#
# Para ello, descargue el dataset de titanic y realice un análisis descriptivo de todos los datos posibles del dataset (emplee los conceptos ya aprendidos en el primer corte.

# %% [markdown]
# ###ANÁLISIS DESCRIPTIVO

# %%
#Realice aquí su análisis descriptivo y emita sus conclusiones. Emplee todas las gráficas necesarias para poder emitir conclusiones con respecto a la tripulación del titanic.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/Ciencia de Datos/titanic-train.csv')

# %% [markdown]
# Cómo podemos llenar los datos nulos?
#
# Los datos disponibles son suficientes para generar un modelo mínimo viable?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [687 rows x 12 columns]

# %%
df=df.dropna(subset=['Age'])

# %%
df.shape
# Out:
# (183, 12)

# %%
df=df.dropna(subset=['Cabin'])

# %%
df=df.dropna(subset=['Embarked'])

# %% [markdown]
# ### AJUSTES DE VARIABLES
# Observemos el dataset de TITANIC:
# * La presentación de todas las variables es la adecuada? Si su respuesta es si, qué tipo de variable posee la feature Age?
# AGE es una variable de tipo float. Queremos que sea de tipo entero. Genere un nuevo dataset con la característica AGE de tipo entero. Así mismo, revise que las características Survived y Pclass sean numéricas.

# %% [markdown]
# ### DETECCIÓN Y TRATAMIENTO DE DATOS AUSENTES
# Como se pudo observar, el dataset de titanic posee una cantidad de (llenar aquí con la información) datos nulos, los cuáles deben ser tratados para un posterior entendimiento de los datos. Ejecute las siguientes líneas de código para arreglar el dataset y explica los resultados obtenidos.

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 1          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# 11         False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 871        False     False   False  False  False  False  False  False   False
# 872        False     False   False  False  False  False  False  False   False
# 879        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 1    False  False     False
# 3    False  False     False
# 6    False  False     False
# 10   False  False     False
# 11   False  False     False
# ..     ...    ...       ...
# 871  False  False     False
# 872  False  False     False
# 879  False  False     False
# 887  False  False     False
# 889  False  False     False
#
# [183 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
total=df.isnull().sum().sort_values(ascending=False)
total
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.isnull().count()
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
porcentajes=(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
porcentajes
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Cabin          0.0
# Embarked       0.0
# dtype: float64

# %%
datos_perdidos=pd.concat([total,porcentajes],axis=1,keys=['Total','Porcentaje'])
datos_perdidos
# Out:
#              Total  Porcentaje
# PassengerId      0         0.0
# Survived         0         0.0
# Pclass           0         0.0
# Name             0         0.0
# Sex              0         0.0
# Age              0         0.0
# SibSp            0         0.0
# Parch            0         0.0
# Ticket           0         0.0
# Fare             0         0.0
# Cabin            0         0.0
# Embarked         0         0.0

# %%
colors = ["darkturquoise", "mediumorchid"]
sns.countplot(data=df, x="Survived",hue="Survived", palette=colors, legend= False)
plt.xlabel("Supervivencia")
plt.ylabel("Cantidad de pasajeros")
plt.title("Supervivientes vs No sobrevivientes")
plt.show()

# %% [markdown]
# Al borrar los datos de los pasajeros que tenían información faltante, obtenemos que la mayoría sobrevivió

# %%
colors2=["darkturquoise","mediumturquoise","paleturquoise"]
sns.countplot(data=df, x="Pclass", hue="Pclass", palette=colors2, legend=False)
plt.xlabel("Clase del pasajero")
plt.ylabel("Cantidad de pasajeros")
plt.title("Distribución de pasajeros por clase")
plt.show()

# %% [markdown]
# Se obtuvo que la mayoría son pertenecientes a la primera clase

# %%
sns.countplot(data=df, x="Sex", hue="Sex", palette=colors, legend=False)
plt.xlabel("Género del pasajero")
plt.ylabel("Cantidad de pasajeros")
plt.title("Distribución de pasajeros por género")
plt.show()

# %%
# Mapea los valores 0 y 1 a texto
df['Survived_label'] = df['Survived'].map({0: 'No sobrevivió', 1: 'Sobrevivió'})

# Crear gráfico con seaborn
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived_label', hue='Sex', palette=colors)

# Títulos y etiquetas
plt.title('Supervivencia por Género', fontsize=14)
plt.xlabel('Resultado', fontsize=12)
plt.ylabel('Cantidad de personas', fontsize=12)
plt.legend(title='Género', labels=['Femenino', 'Masculino'])

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Vemos que la mayoría de los que sobrevivieron fueron mujeres

# %%
sns.histplot(data=df, x="Age", kde=True)
plt.xlabel("Edad del pasajero")
plt.ylabel("Frecuencia")
plt.title("Distribución de edades de los pasajeros")
plt.show()

# %%
# Mapea los valores 0 y 1 a texto
df['Survived_label'] = df['Survived'].map({0: 'No sobrevivió', 1: 'Sobrevivió'})

# Crear gráfico con seaborn
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived_label', palette=colors2)

# Títulos y etiquetas
plt.title('Supervivencia por Edad', fontsize=14)
plt.xlabel('Resultado', fontsize=12)
plt.ylabel('Cantidad de personas', fontsize=12)

# Mostrar gráfico
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-333053b672a0>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Survived_label', palette=colors2)
# <ipython-input-49-333053b672a0>:6: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.countplot(data=df, x='Survived_label', palette=colors2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Suponiendo que tienes un DataFrame con columnas 'Survived' y 'Age'
sns.boxplot(x='Survived', y='Age', data=df)
plt.xticks([0, 1], ['No sobrevivió', 'Sobrevivió'])
plt.title('Distribución de edad según supervivencia')
plt.show()

# %% [markdown]
# La mayoría de los que sobrevivió son más jóvenes

# %%
df_numeric = df.select_dtypes(include=["number"])
df_numeric.corr().style.background_gradient(cmap="coolwarm").format(precision=2)
# Out:
# <style type="text/css">
# #T_b4bb3_row0_col0, #T_b4bb3_row1_col1, #T_b4bb3_row2_col2, #T_b4bb3_row3_col3, #T_b4bb3_row4_col4, #T_b4bb3_row5_col5, #T_b4bb3_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b4bb3_row0_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b4bb3_row0_col2, #T_b4bb3_row0_col5, #T_b4bb3_row2_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b4bb3_row0_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b4bb3_row0_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b4bb3_row0_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b4bb3_row1_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b4bb3_row1_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b4bb3_row1_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b4bb3_row1_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b4bb3_row1_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b4bb3_row1_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b4bb3_row2_col0, #T_b4bb3_row2_col3, #T_b4bb3_row2_col6, #T_b4bb3_row3_col1, #T_b4bb3_row3_col4, #T_b4bb3_row3_col5, #T_b4bb3_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b4bb3_row2_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b4bb3_row2_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b4bb3_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b4bb3_row3_col2, #T_b4bb3_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b4bb3_row3_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b4bb3_row4_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b4bb3_row4_col2, #T_b4bb3_row6_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b4bb3_row4_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b4bb3_row4_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b4bb3_row4_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b4bb3_row5_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b4bb3_row5_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b4bb3_row5_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b4bb3_row5_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b4bb3_row5_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b4bb3_row5_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b4bb3_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b4bb3_row6_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b4bb3_row6_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b4bb3_row6_col5 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# </style>
# <table id="T_b4bb3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4bb3_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_b4bb3_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_b4bb3_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_b4bb3_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_b4bb3_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_b4bb3_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_b4bb3_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4bb3_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_b4bb3_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_b4bb3_row0_col1" class="data row0 col1" >0.15</td>
#       <td id="T_b4bb3_row0_col2" class="data row0 col2" >-0.09</td>
#       <td id="T_b4bb3_row0_col3" class="data row0 col3" >0.03</td>
#       <td id="T_b4bb3_row0_col4" class="data row0 col4" >-0.08</td>
#       <td id="T_b4bb3_row0_col5" class="data row0 col5" >-0.05</td>
#       <td id="T_b4bb3_row0_col6" class="data row0 col6" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_b4bb3_row1_col0" class="data row1 col0" >0.15</td>
#       <td id="T_b4bb3_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_b4bb3_row1_col2" class="data row1 col2" >-0.03</td>
#       <td id="T_b4bb3_row1_col3" class="data row1 col3" >-0.25</td>
#       <td id="T_b4bb3_row1_col4" class="data row1 col4" >0.11</td>
#       <td id="T_b4bb3_row1_col5" class="data row1 col5" >0.02</td>
#       <td id="T_b4bb3_row1_col6" class="data row1 col6" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_b4bb3_row2_col0" class="data row2 col0" >-0.09</td>
#       <td id="T_b4bb3_row2_col1" class="data row2 col1" >-0.03</td>
#       <td id="T_b4bb3_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_b4bb3_row2_col3" class="data row2 col3" >-0.31</td>
#       <td id="T_b4bb3_row2_col4" class="data row2 col4" >-0.10</td>
#       <td id="T_b4bb3_row2_col5" class="data row2 col5" >0.05</td>
#       <td id="T_b4bb3_row2_col6" class="data row2 col6" >-0.32</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_b4bb3_row3_col0" class="data row3 col0" >0.03</td>
#       <td id="T_b4bb3_row3_col1" class="data row3 col1" >-0.25</td>
#       <td id="T_b4bb3_row3_col2" class="data row3 col2" >-0.31</td>
#       <td id="T_b4bb3_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_b4bb3_row3_col4" class="data row3 col4" >-0.16</td>
#       <td id="T_b4bb3_row3_col5" class="data row3 col5" >-0.27</td>
#       <td id="T_b4bb3_row3_col6" class="data row3 col6" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_b4bb3_row4_col0" class="data row4 col0" >-0.08</td>
#       <td id="T_b4bb3_row4_col1" class="data row4 col1" >0.11</td>
#       <td id="T_b4bb3_row4_col2" class="data row4 col2" >-0.10</td>
#       <td id="T_b4bb3_row4_col3" class="data row4 col3" >-0.16</td>
#       <td id="T_b4bb3_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_b4bb3_row4_col5" class="data row4 col5" >0.26</td>
#       <td id="T_b4bb3_row4_col6" class="data row4 col6" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_b4bb3_row5_col0" class="data row5 col0" >-0.05</td>
#       <td id="T_b4bb3_row5_col1" class="data row5 col1" >0.02</td>
#       <td id="T_b4bb3_row5_col2" class="data row5 col2" >0.05</td>
#       <td id="T_b4bb3_row5_col3" class="data row5 col3" >-0.27</td>
#       <td id="T_b4bb3_row5_col4" class="data row5 col4" >0.26</td>
#       <td id="T_b4bb3_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_b4bb3_row5_col6" class="data row5 col6" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_b4bb3_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_b4bb3_row6_col0" class="data row6 col0" >0.03</td>
#       <td id="T_b4bb3_row6_col1" class="data row6 col1" >0.13</td>
#       <td id="T_b4bb3_row6_col2" class="data row6 col2" >-0.32</td>
#       <td id="T_b4bb3_row6_col3" class="data row6 col3" >-0.09</td>
#       <td id="T_b4bb3_row6_col4" class="data row6 col4" >0.29</td>
#       <td id="T_b4bb3_row6_col5" class="data row6 col5" >0.39</td>
#       <td id="T_b4bb3_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Se puede observar que, en cuanto a la supervivencia, la edad tiene la mayor correlación con la misma, lo que indica que mientras mayor edad tenga la persona, mayor es su probabilidad de no sobrevivir.
# También se puede observar que, las personas mayores eran las que pertenecían a las clases más altas.
#
# Se ve, además, que quienes pagaron más tuvieron mayores porcentajes de sobrevivir

# %%
def plot_learning_curve(estimator,title,X,y,xlim=None,cv=None,n_jobs=1,train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Ejemplos de entrenamiento")
    plt.ylabel("Puntuación de validación")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Puntuación de entrenamiento")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Puntuación de validación")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# Explique línea por línea qué está haciendo la función plot_learning_curve (responda preguntas como, qué tipo de datos solicita, qué otros valores se pueden usar, cuál es su uso, etc.). También explique la gráfica obtenida.
#
# El resultado de esta actividad debe subirse a GITHUB el día 7 de abril/2025 a las 5:00pm.
# **Actividades subidas en la franja de 5:01pm a 11:59pm será evaluado sobre 4.0.**
#
# **Actividades subidas después del 7 de abril pero antes de la siguiente clase serán evaluadas sobre 3.0.**

# %% [markdown]
# ##Para investigar:
# Formule una estrategia que permita llenar los datos nulos del dataset y empléelo. Ejemplo: cómo podría llenar los datos nulos de edades?
